# %%
import pandas as pd

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Sales2.csv')

# %%
df.head()
# Out:
#    Unnamed: 0   Brands        Models         Colors Memory Storage Camera  \
# 0           0  SAMSUNG  GALAXY M31S    Mirage Black   8 GB  128 GB    Yes
# 1           1    Nokia           3.2          Steel   2 GB   16 GB    Yes
# 2           2   realme           C2   Diamond Black   2 GB     NaN    Yes
# 3           3  Infinix        Note 5       Ice Blue   4 GB   64 GB    Yes
# 4           4    Apple    iPhone 11           Black    4GB   64 GB    Yes
#
#    Rating  Selling Price  Original Price                Mobile  Discount  \
# 0     4.3          19330           20999  SAMSUNG GALAXY M31S       1669
# 1     3.8          10199           10199             Nokia 3.2         0
# 2     4.4           6999            7999            realme C2       1000
# 3     4.2          12999           12999        Infinix Note 5         0
# 4     4.6          49900           49900      Apple iPhone 11          0
#
#    discount percentage Selling Price-binned
# ...

# %%
df[['Profit/loss Perentage']]=np.round(df[['Profit/loss Perentage']],3)

# %%
df.head()
# Out:
#    Unnamed: 0   Brands        Models         Colors Memory Storage Camera  \
# 0           0  SAMSUNG  GALAXY M31S    Mirage Black   8 GB  128 GB    Yes
# 1           1    Nokia           3.2          Steel   2 GB   16 GB    Yes
# 2           2   realme           C2   Diamond Black   2 GB     NaN    Yes
# 3           3  Infinix        Note 5       Ice Blue   4 GB   64 GB    Yes
# 4           4    Apple    iPhone 11           Black    4GB   64 GB    Yes
#
#    Rating  Selling Price  Original Price                Mobile  Discount  \
# 0     4.3          19330           20999  SAMSUNG GALAXY M31S       1669
# 1     3.8          10199           10199             Nokia 3.2         0
# 2     4.4           6999            7999            realme C2       1000
# 3     4.2          12999           12999        Infinix Note 5         0
# 4     4.6          49900           49900      Apple iPhone 11          0
#
#    discount percentage Selling Price-binned
# ...

# %%
max(df['discount percentage'])
# Out:
# 70.61

# %%
min(df['discount percentage'])
# Out:
# -160.321

# %%
df.loc[df['discount percentage']==-160.321]
# Out:
#       Unnamed: 0 Brands Models Colors Memory Storage Camera  Rating  \
# 2137        2137   OPPO    A5s    Red   2 GB   32 GB    Yes     4.3
#
#       Selling Price  Original Price    Mobile  Discount  discount percentage  \
# 2137          12990            4990  OPPO A5s     -8000             -160.321
#
#      Selling Price-binned
# 2137                  Low

# %%
df.rename(columns={'Original Price':'Purchase Price','Discount':'Profit/loss','discount percentage':'Profit/loss Perentage'},inplace=True)

# %%
df.to_csv('Sales3.csv')

# %%
df['Profit/Loss Culc'] = df['Selling Price']-df['Purchase Price']
df
# Out:
#       Unnamed: 0   Brands          Models         Colors Memory  \
# 0              0  SAMSUNG    GALAXY M31S    Mirage Black   8 GB
# 1              1    Nokia             3.2          Steel   2 GB
# 2              2   realme             C2   Diamond Black   2 GB
# 3              3  Infinix          Note 5       Ice Blue   4 GB
# 4              4    Apple      iPhone 11           Black    4GB
# ...          ...      ...             ...            ...    ...
# 3109        3109     POCO       M4 Pro 5G      Cool Blue   6 GB
# 3110        3110    Nokia             225          Black    NaN
# 3111        3111    Apple      iPhone SE           White   2 GB
# 3112        3112    Apple  iPhone 13 Pro            Gold   6 GB
# 3113        3113   GIONEE             F9            Blue   3 GB
#
#                     Storage Camera  Rating  Selling Price  Purchase Price  \
# 0                    128 GB    Yes     4.3          19330           20999
# ...

# %%
max(df['Profit/Loss Culc'])
# Out:
# 8000

# %%
min(df['Profit/Loss Culc'])
# Out:
# -75000

# %%
df.iloc['Profit/Loss']
# Out:
# Unnamed: 0                                10
# Brands                               SAMSUNG
# Models                           Galaxy A12
# Colors                                 Black
# Memory                                  4 GB
# Storage                                64 GB
# Camera                                   Yes
# Rating                                   4.2
# Selling Price                          11989
# Purchase Price                         11989
# Mobile                   SAMSUNG Galaxy A12
# Profit/loss                                0
# Profit/loss Perentage                    0.0
# Selling Price-binned                     Low
# Profit/Loss                                0
# Name: 10, dtype: object

# %%
del df['Profit/Loss']

# %%
df.head()
# Out:
#    Unnamed: 0   Brands        Models         Colors Memory Storage Camera  \
# 0           0  SAMSUNG  GALAXY M31S    Mirage Black   8 GB  128 GB    Yes
# 1           1    Nokia           3.2          Steel   2 GB   16 GB    Yes
# 2           2   realme           C2   Diamond Black   2 GB     NaN    Yes
# 3           3  Infinix        Note 5       Ice Blue   4 GB   64 GB    Yes
# 4           4    Apple    iPhone 11           Black    4GB   64 GB    Yes
#
#    Rating  Selling Price  Purchase Price                Mobile  Profit/loss  \
# 0     4.3          19330           20999  SAMSUNG GALAXY M31S          1669
# 1     3.8          10199           10199             Nokia 3.2            0
# 2     4.4           6999            7999            realme C2          1000
# 3     4.2          12999           12999        Infinix Note 5            0
# 4     4.6          49900           49900      Apple iPhone 11             0
#
#    Profit/loss Perentage Selling Price-binned  Profit/Loss Culc
# ...

# %%
df['%Profit/Loss'] =((df['Selling Price']/df['Purchase Price'])*100)-100

# %%
df.head()
# Out:
#    Unnamed: 0   Brands        Models         Colors Memory Storage Camera  \
# 0           0  SAMSUNG  GALAXY M31S    Mirage Black   8 GB  128 GB    Yes
# 1           1    Nokia           3.2          Steel   2 GB   16 GB    Yes
# 2           2   realme           C2   Diamond Black   2 GB     NaN    Yes
# 3           3  Infinix        Note 5       Ice Blue   4 GB   64 GB    Yes
# 4           4    Apple    iPhone 11           Black    4GB   64 GB    Yes
#
#    Rating  Selling Price  Purchase Price                Mobile  Profit/loss  \
# 0     4.3          19330           20999  SAMSUNG GALAXY M31S          1669
# 1     3.8          10199           10199             Nokia 3.2            0
# 2     4.4           6999            7999            realme C2          1000
# 3     4.2          12999           12999        Infinix Note 5            0
# 4     4.6          49900           49900      Apple iPhone 11             0
#
# ...

# %%
df[['%Profit/Loss']]=np.round(df[['%Profit/Loss']],2)
df.head()
# Out:
#    Unnamed: 0   Brands        Models         Colors Memory Storage Camera  \
# 0           0  SAMSUNG  GALAXY M31S    Mirage Black   8 GB  128 GB    Yes
# 1           1    Nokia           3.2          Steel   2 GB   16 GB    Yes
# 2           2   realme           C2   Diamond Black   2 GB     NaN    Yes
# 3           3  Infinix        Note 5       Ice Blue   4 GB   64 GB    Yes
# 4           4    Apple    iPhone 11           Black    4GB   64 GB    Yes
#
#    Rating  Selling Price  Purchase Price                Mobile  Profit/loss  \
# 0     4.3          19330           20999  SAMSUNG GALAXY M31S          1669
# 1     3.8          10199           10199             Nokia 3.2            0
# 2     4.4           6999            7999            realme C2          1000
# 3     4.2          12999           12999        Infinix Note 5            0
# 4     4.6          49900           49900      Apple iPhone 11             0
#
# ...

# %%
min(df['%Profit/Loss'])
# Out:
# -70.61

# %%
max(df['%Profit/Loss'])
# Out:
# 160.32

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
plt.pyplot.hist(df['%Profit/Loss'])

plt.pyplot.xlabel('%Profit/Loss')
plt.pyplot.ylabel('count')
plt.pyplot.title('Phone Proft')
# Out:
# Text(0.5, 1.0, 'Phone Proft')

# %%
df.to_csv('Sales4.csv')
